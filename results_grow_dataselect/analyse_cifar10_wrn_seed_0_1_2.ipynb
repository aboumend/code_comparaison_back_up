# %%
import csv
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
def get_data_from_csv_file(file_name):
    with open(file_name) as f:
        rows=csv.reader(f, delimiter=',')
        steps=[]
        values=[]
        i=0
        for row in rows:
            if (i==0): 
                i+=1
                continue
            else:
                steps.append(int(row[1]))
                values.append(float(row[2]))
    return steps, values

# %%
dico_global_seed0={}
global_path="./test_seed_0/mesure_powermetrics"

dico={}
path=os.path.join(global_path, "baseline_big")
path=os.path.join(path, "stats_tensorboard")


dico['test_steps'], dico['test_acc']=get_data_from_csv_file(os.path.join(path, "test_acc.csv"))
_, dico['test_loss']=get_data_from_csv_file(os.path.join(path, "test_negative_log.csv"))

dico['train_steps'], dico['train_acc']=get_data_from_csv_file(os.path.join(path, "train_acc.csv"))
_, dico['train_loss']=get_data_from_csv_file(os.path.join(path, "train_negative_log.csv"))

dico_global_seed0['baseline_big']=dico

dico={}
path=os.path.join(global_path, "data_select_50")
path=os.path.join(path, "stats_tensorboard")


dico['test_steps'], dico['test_acc']=get_data_from_csv_file(os.path.join(path, "test_acc.csv"))
_, dico['test_loss']=get_data_from_csv_file(os.path.join(path, "test_negative_log.csv"))

dico['train_steps'], dico['train_acc']=get_data_from_csv_file(os.path.join(path, "train_acc.csv"))
_, dico['train_loss']=get_data_from_csv_file(os.path.join(path, "train_negative_log.csv"))

dico_global_seed0['data_select_50']=dico

dico={}
path=os.path.join(global_path, "gradmax")
path=os.path.join(path, "stats_tensorboard")


dico['test_steps'], dico['test_acc']=get_data_from_csv_file(os.path.join(path, "test_acc.csv"))
_, dico['test_loss']=get_data_from_csv_file(os.path.join(path, "test_negative_log.csv"))

dico['train_steps'], dico['train_acc']=get_data_from_csv_file(os.path.join(path, "train_acc.csv"))
_, dico['train_loss']=get_data_from_csv_file(os.path.join(path, "train_negative_log.csv"))

dico_global_seed0['gradmax']=dico

# %%
dico_global_seed1={}
global_path="./test_seed_1/mesure_powermetrics"

dico={}
path=os.path.join(global_path, "baseline_big")
path=os.path.join(path, "stats_tensorboard")


dico['test_steps'], dico['test_acc']=get_data_from_csv_file(os.path.join(path, "test_acc.csv"))
_, dico['test_loss']=get_data_from_csv_file(os.path.join(path, "test_negative_log.csv"))

dico['train_steps'], dico['train_acc']=get_data_from_csv_file(os.path.join(path, "train_acc.csv"))
_, dico['train_loss']=get_data_from_csv_file(os.path.join(path, "train_negative_log.csv"))

dico_global_seed1['baseline_big']=dico

dico={}
path=os.path.join(global_path, "data_select_50")
path=os.path.join(path, "stats_tensorboard")


dico['test_steps'], dico['test_acc']=get_data_from_csv_file(os.path.join(path, "test_acc.csv"))
_, dico['test_loss']=get_data_from_csv_file(os.path.join(path, "test_negative_log.csv"))

dico['train_steps'], dico['train_acc']=get_data_from_csv_file(os.path.join(path, "train_acc.csv"))
_, dico['train_loss']=get_data_from_csv_file(os.path.join(path, "train_negative_log.csv"))

dico_global_seed1['data_select_50']=dico

dico={}
path=os.path.join(global_path, "gradmax")
path=os.path.join(path, "stats_tensorboard")


dico['test_steps'], dico['test_acc']=get_data_from_csv_file(os.path.join(path, "test_acc.csv"))
_, dico['test_loss']=get_data_from_csv_file(os.path.join(path, "test_negative_log.csv"))

dico['train_steps'], dico['train_acc']=get_data_from_csv_file(os.path.join(path, "train_acc.csv"))
_, dico['train_loss']=get_data_from_csv_file(os.path.join(path, "train_negative_log.csv"))

dico_global_seed1['gradmax']=dico

# %%
dico_global_seed2={}
global_path="./test_seed_2/mesure_powermetrics"

dico={}
path=os.path.join(global_path, "baseline_big")
path=os.path.join(path, "stats_tensorboard")


dico['test_steps'], dico['test_acc']=get_data_from_csv_file(os.path.join(path, "test_acc.csv"))
_, dico['test_loss']=get_data_from_csv_file(os.path.join(path, "test_negative_log.csv"))

dico['train_steps'], dico['train_acc']=get_data_from_csv_file(os.path.join(path, "train_acc.csv"))
_, dico['train_loss']=get_data_from_csv_file(os.path.join(path, "train_negative_log.csv"))

dico_global_seed2['baseline_big']=dico

dico={}
path=os.path.join(global_path, "data_select_50")
path=os.path.join(path, "stats_tensorboard")


dico['test_steps'], dico['test_acc']=get_data_from_csv_file(os.path.join(path, "test_acc.csv"))
_, dico['test_loss']=get_data_from_csv_file(os.path.join(path, "test_negative_log.csv"))

dico['train_steps'], dico['train_acc']=get_data_from_csv_file(os.path.join(path, "train_acc.csv"))
_, dico['train_loss']=get_data_from_csv_file(os.path.join(path, "train_negative_log.csv"))

dico_global_seed2['data_select_50']=dico

dico={}
path=os.path.join(global_path, "gradmax")
path=os.path.join(path, "stats_tensorboard")


dico['test_steps'], dico['test_acc']=get_data_from_csv_file(os.path.join(path, "test_acc.csv"))
_, dico['test_loss']=get_data_from_csv_file(os.path.join(path, "test_negative_log.csv"))

dico['train_steps'], dico['train_acc']=get_data_from_csv_file(os.path.join(path, "train_acc.csv"))
_, dico['train_loss']=get_data_from_csv_file(os.path.join(path, "train_negative_log.csv"))

dico_global_seed2['gradmax']=dico

# %%
fig, ax= plt.subplots(nrows=3, ncols=2, figsize=(15,15))
ax[0,0].plot(dico_global_seed0['baseline_big']['test_steps'], dico_global_seed0['baseline_big']['test_acc'], label="baseline")
ax[0,0].plot(dico_global_seed0['data_select_50']['test_steps'], dico_global_seed0['data_select_50']['test_acc'], label="data select 50%")
ax[0,0].plot(dico_global_seed0['gradmax']['test_steps'], dico_global_seed0['gradmax']['test_acc'], label="gradmax")
ax[0,0].legend()
ax[0,0].set_title("évolution test accuracy seed 0")
ax[0,0].set_xlabel("epochs")
ax[0,0].set_ylabel("test accuracy")

ax[0,1].plot(dico_global_seed0['baseline_big']['train_steps'], dico_global_seed0['baseline_big']['train_acc'], label="baseline")
ax[0,1].plot(dico_global_seed0['data_select_50']['train_steps'], dico_global_seed0['data_select_50']['train_acc'], label="data select 50%")
ax[0,1].plot(dico_global_seed0['gradmax']['train_steps'], dico_global_seed0['gradmax']['train_acc'], label="gradmax")
ax[0,1].legend()
ax[0,1].set_title("évolution train accuracy seed 0")
ax[0,1].set_xlabel("iterations")
ax[0,1].set_ylabel("train accuracy")




ax[1,0].plot(dico_global_seed1['baseline_big']['test_steps'], dico_global_seed1['baseline_big']['test_acc'], label="baseline")
ax[1,0].plot(dico_global_seed1['data_select_50']['test_steps'], dico_global_seed1['data_select_50']['test_acc'], label="data select 50%")
ax[1,0].plot(dico_global_seed1['gradmax']['test_steps'], dico_global_seed1['gradmax']['test_acc'], label="gradmax")
ax[1,0].legend()
ax[1,0].set_title("évolution test accuracy seed 1")
ax[1,0].set_xlabel("epochs")
ax[1,0].set_ylabel("test accuracy")


ax[1,1].plot(dico_global_seed1['baseline_big']['train_steps'], dico_global_seed1['baseline_big']['train_acc'], label="baseline")
ax[1,1].plot(dico_global_seed1['data_select_50']['train_steps'], dico_global_seed1['data_select_50']['train_acc'], label="data select 50%")
ax[1,1].plot(dico_global_seed1['gradmax']['train_steps'], dico_global_seed1['gradmax']['train_acc'], label="gradmax")
ax[1,1].legend()
ax[1,1].set_title("évolution train accuracy seed 1")
ax[1,1].set_xlabel("iterations")
ax[1,1].set_ylabel("train accuracy")



ax[2,0].plot(dico_global_seed2['baseline_big']['test_steps'], dico_global_seed2['baseline_big']['test_acc'], label="baseline")
ax[2,0].plot(dico_global_seed2['data_select_50']['test_steps'], dico_global_seed2['data_select_50']['test_acc'], label="data select 50%")
ax[2,0].plot(dico_global_seed2['gradmax']['test_steps'], dico_global_seed2['gradmax']['test_acc'], label="gradmax")
ax[2,0].legend()
ax[2,0].set_title("évolution test accuracy seed 2")
ax[2,0].set_xlabel("epochs")
ax[2,0].set_ylabel("test accuracy")


ax[2,1].plot(dico_global_seed2['baseline_big']['train_steps'], dico_global_seed2['baseline_big']['train_acc'], label="baseline")
ax[2,1].plot(dico_global_seed2['data_select_50']['train_steps'], dico_global_seed2['data_select_50']['train_acc'], label="data select 50%")
ax[2,1].plot(dico_global_seed2['gradmax']['train_steps'], dico_global_seed2['gradmax']['train_acc'], label="gradmax")
ax[2,1].legend()
ax[2,1].set_title("évolution train accuracy seed 2")
ax[2,1].set_xlabel("iterations")
ax[2,1].set_ylabel("train accuracy")
# Out:
# Text(0, 0.5, 'train accuracy')

# %%
dico_moyenne={}


dico={}

moy=np.array(dico_global_seed0['baseline_big']['test_acc'])+np.array(dico_global_seed1['baseline_big']['test_acc'])+np.array(dico_global_seed2['baseline_big']['test_acc'])
moy=moy/3
dico['test_steps'], dico['test_acc']=dico_global_seed0['baseline_big']['test_steps'], moy

moy=np.array(dico_global_seed0['baseline_big']['test_loss'])+np.array(dico_global_seed1['baseline_big']['test_loss'])+np.array(dico_global_seed2['baseline_big']['test_loss'])
moy=moy/3
dico['test_steps'], dico['test_loss']=dico_global_seed0['baseline_big']['test_steps'], moy

moy=np.array(dico_global_seed0['baseline_big']['train_acc'])+np.array(dico_global_seed1['baseline_big']['train_acc'])+np.array(dico_global_seed2['baseline_big']['train_acc'])
moy=moy/3
dico['train_steps'], dico['train_acc']=dico_global_seed0['baseline_big']['train_steps'], moy

moy=np.array(dico_global_seed0['baseline_big']['train_loss'])+np.array(dico_global_seed1['baseline_big']['train_loss'])+np.array(dico_global_seed2['baseline_big']['train_loss'])
moy=moy/3
dico['train_steps'], dico['train_loss']=dico_global_seed0['baseline_big']['train_steps'], moy

dico_moyenne['baseline_big']=dico


dico={}

moy=np.array(dico_global_seed0['data_select_50']['test_acc'])+np.array(dico_global_seed1['data_select_50']['test_acc'])+np.array(dico_global_seed2['data_select_50']['test_acc'])
moy=moy/3
dico['test_steps'], dico['test_acc']=dico_global_seed0['data_select_50']['test_steps'], moy

moy=np.array(dico_global_seed0['data_select_50']['test_loss'])+np.array(dico_global_seed1['data_select_50']['test_loss'])+np.array(dico_global_seed2['data_select_50']['test_loss'])
moy=moy/3
dico['test_steps'], dico['test_loss']=dico_global_seed0['data_select_50']['test_steps'], moy


l=min(len(dico_global_seed0['data_select_50']['train_acc']), len(dico_global_seed1['data_select_50']['train_acc']), len(dico_global_seed2['data_select_50']['train_acc']))


moy=np.array(dico_global_seed0['data_select_50']['train_acc'][0:l])+np.array(dico_global_seed1['data_select_50']['train_acc'][0:l])+np.array(dico_global_seed2['data_select_50']['train_acc'][0:l])
moy=moy/3
dico['train_steps'], dico['train_acc']=dico_global_seed0['data_select_50']['train_steps'][0:l], moy

moy=np.array(dico_global_seed0['data_select_50']['train_loss'][0:l])+np.array(dico_global_seed1['data_select_50']['train_loss'][0:l])+np.array(dico_global_seed2['data_select_50']['train_loss'][0:l])
moy=moy/3
dico['train_steps'], dico['train_loss']=dico_global_seed0['data_select_50']['train_steps'][0:l], moy

dico_moyenne['data_select_50']=dico



dico={}

moy=np.array(dico_global_seed0['gradmax']['test_acc'])+np.array(dico_global_seed1['gradmax']['test_acc'])+np.array(dico_global_seed2['gradmax']['test_acc'])
moy=moy/3
dico['test_steps'], dico['test_acc']=dico_global_seed0['gradmax']['test_steps'], moy

moy=np.array(dico_global_seed0['gradmax']['test_loss'])+np.array(dico_global_seed1['gradmax']['test_loss'])+np.array(dico_global_seed2['gradmax']['test_loss'])
moy=moy/3
dico['test_steps'], dico['test_loss']=dico_global_seed0['gradmax']['test_steps'], moy

moy=np.array(dico_global_seed0['gradmax']['train_acc'])+np.array(dico_global_seed1['gradmax']['train_acc'])+np.array(dico_global_seed2['gradmax']['train_acc'])
moy=moy/3
dico['train_steps'], dico['train_acc']=dico_global_seed0['gradmax']['train_steps'], moy

moy=np.array(dico_global_seed0['gradmax']['train_loss'])+np.array(dico_global_seed1['gradmax']['train_loss'])+np.array(dico_global_seed2['gradmax']['train_loss'])
moy=moy/3
dico['train_steps'], dico['train_loss']=dico_global_seed0['gradmax']['train_steps'], moy

dico_moyenne['gradmax']=dico

# %%
fig, ax= plt.subplots(nrows=2, ncols=2, figsize=(15,15))

ax[0,0].plot(dico_moyenne['baseline_big']['train_steps'], dico_moyenne['baseline_big']['train_acc'], label="baseline")
ax[0,0].plot(dico_moyenne['data_select_50']['train_steps'], dico_moyenne['data_select_50']['train_acc'], label="data selection 50%")
ax[0,0].plot(dico_moyenne['gradmax']['train_steps'], dico_moyenne['gradmax']['train_acc'], label="gradmax")
ax[0,0].set_title("évolution train accuracy")
ax[0,0].set_xlabel("iterations")
ax[0,0].set_ylabel("train accuracy")
ax[0,0].legend()



ax[0,1].plot(dico_moyenne['baseline_big']['train_steps'], dico_moyenne['baseline_big']['train_loss'], label="baseline")
ax[0,1].plot(dico_moyenne['data_select_50']['train_steps'], dico_moyenne['data_select_50']['train_loss'], label="data selection 50%")
ax[0,1].plot(dico_moyenne['gradmax']['train_steps'], dico_moyenne['gradmax']['train_loss'], label="gradmax")
ax[0,1].set_title("évolution train loss")
ax[0,1].set_xlabel("iterations")
ax[0,1].set_ylabel("train loss")
ax[0,1].legend()
ax[0,1].set_yscale('log')



ax[1,0].plot(dico_moyenne['baseline_big']['test_steps'], dico_moyenne['baseline_big']['test_acc'], label="baseline")
ax[1,0].plot(dico_moyenne['data_select_50']['test_steps'], dico_moyenne['data_select_50']['test_acc'], label="data selection 50%")
ax[1,0].plot(dico_moyenne['gradmax']['test_steps'], dico_moyenne['gradmax']['test_acc'], label="gradmax")
ax[1,0].set_title("évolution test accuracy")
ax[1,0].set_xlabel("epochs")
ax[1,0].set_ylabel("test accuracy")
ax[1,0].legend()



ax[1,1].plot(dico_moyenne['baseline_big']['test_steps'], dico_moyenne['baseline_big']['test_loss'], label="baseline")
ax[1,1].plot(dico_moyenne['data_select_50']['test_steps'], dico_moyenne['data_select_50']['test_loss'], label="data selection 50%")
ax[1,1].plot(dico_moyenne['gradmax']['test_steps'], dico_moyenne['gradmax']['test_loss'], label="gradmax")
ax[1,1].set_title("évolution test loss")
ax[1,1].set_xlabel("epochs")
ax[1,1].set_ylabel("test loss")
ax[1,1].legend()
ax[1,1].set_yscale('log')

# %%
def get_power_stats(file):
    f=open(file, 'r')
    lines = f.readlines()
    power_list=[]
    power_avg=0


    for line in lines:
        power_list.append(int(line))
        power_avg+=int(line)

    power_avg/=len(lines)
    power_avg/=1000 #conversion en watt
    
    energy= power_avg * len(lines)
    train_time=len(lines)
    return power_list, power_avg, train_time, energy

# %%
dico_energy_seed0={}
dico_power_list_seed0={}
dico_power_avg_seed0={}
dico_train_time_seed0={}

path="./test_seed_0/mesure_powermetrics/baseline_big/mesure_baseline_big.txt"
pw_list, pw_avg, train_time, energy= get_power_stats(path)
dico_energy_seed0['baseline_big']=energy
dico_power_list_seed0['baseline_big']=pw_list
dico_power_avg_seed0['baseline_big']=pw_avg
dico_train_time_seed0['baseline_big']=train_time

path="./test_seed_0/mesure_powermetrics/data_select_50/mesure_data_select_50.txt"
pw_list, pw_avg, train_time, energy= get_power_stats(path)
dico_energy_seed0['data_select_50']=energy
dico_power_list_seed0['data_select_50']=pw_list
dico_power_avg_seed0['data_select_50']=pw_avg
dico_train_time_seed0['data_select_50']=train_time

path="./test_seed_0/mesure_powermetrics/gradmax/mesure_gradmax.txt"
pw_list, pw_avg, train_time, energy= get_power_stats(path)
dico_energy_seed0['gradmax']=energy
dico_power_list_seed0['gradmax']=pw_list
dico_power_avg_seed0['gradmax']=pw_avg
dico_train_time_seed0['gradmax']=train_time

print("------------------------------------ Exécution seed 0 ------------------------------------")
print("baseline big       | power avg =", dico_power_avg_seed0['baseline_big'], "| energy (j)=", dico_energy_seed0['baseline_big'])
print("data selection 50% | power avg =", dico_power_avg_seed0['data_select_50'], "| energy (j)=", dico_energy_seed0['data_select_50'])
print("gradmax            | power avg =", dico_power_avg_seed0['gradmax'], "| energy (j)=", dico_energy_seed0['gradmax'])



print()

dico_energy_seed1={}
dico_power_list_seed1={}
dico_power_avg_seed1={}
dico_train_time_seed1={}

path="./test_seed_1/mesure_powermetrics/baseline_big/mesure_baseline_big.txt"
pw_list, pw_avg, train_time, energy= get_power_stats(path)
dico_energy_seed1['baseline_big']=energy
dico_power_list_seed1['baseline_big']=pw_list
dico_power_avg_seed1['baseline_big']=pw_avg
dico_train_time_seed1['baseline_big']=train_time

path="./test_seed_1/mesure_powermetrics/data_select_50/mesure_data_select_50.txt"
pw_list, pw_avg, train_time, energy= get_power_stats(path)
dico_energy_seed1['data_select_50']=energy
dico_power_list_seed1['data_select_50']=pw_list
dico_power_avg_seed1['data_select_50']=pw_avg
dico_train_time_seed1['data_select_50']=train_time

path="./test_seed_1/mesure_powermetrics/gradmax/mesure_gradmax.txt"
pw_list, pw_avg, train_time, energy= get_power_stats(path)
dico_energy_seed1['gradmax']=energy
dico_power_list_seed1['gradmax']=pw_list
dico_power_avg_seed1['gradmax']=pw_avg
dico_train_time_seed1['gradmax']=train_time

print("------------------------------------ Exécution seed 1 ------------------------------------")
print("baseline big       | power avg =", dico_power_avg_seed1['baseline_big'], "| energy (j)=", dico_energy_seed1['baseline_big'])
print("data selection 50% | power avg =", dico_power_avg_seed1['data_select_50'], "| energy (j)=", dico_energy_seed1['data_select_50'])
print("gradmax            | power avg =", dico_power_avg_seed1['gradmax'], "| energy (j)=", dico_energy_seed1['gradmax'])



print()
dico_energy_seed2={}
dico_power_list_seed2={}
dico_power_avg_seed2={}
dico_train_time_seed2={}

path="./test_seed_2/mesure_powermetrics/baseline_big/mesure_baseline_big.txt"
pw_list, pw_avg, train_time, energy= get_power_stats(path)
dico_energy_seed2['baseline_big']=energy
dico_power_list_seed2['baseline_big']=pw_list
dico_power_avg_seed2['baseline_big']=pw_avg
dico_train_time_seed2['baseline_big']=train_time

path="./test_seed_2/mesure_powermetrics/data_select_50/mesure_data_select_50.txt"
pw_list, pw_avg, train_time, energy= get_power_stats(path)
dico_energy_seed2['data_select_50']=energy
dico_power_list_seed2['data_select_50']=pw_list
dico_power_avg_seed2['data_select_50']=pw_avg
dico_train_time_seed2['data_select_50']=train_time

path="./test_seed_2/mesure_powermetrics/gradmax/mesure_gradmax.txt"
pw_list, pw_avg, train_time, energy= get_power_stats(path)
dico_energy_seed2['gradmax']=energy
dico_power_list_seed2['gradmax']=pw_list
dico_power_avg_seed2['gradmax']=pw_avg
dico_train_time_seed2['gradmax']=train_time

print("------------------------------------ Exécution seed 2 ------------------------------------")
print("baseline big       | power avg =", dico_power_avg_seed2['baseline_big'], "| energy (j)=", dico_energy_seed2['baseline_big'])
print("data selection 50% | power avg =", dico_power_avg_seed2['data_select_50'], "| energy (j)=", dico_energy_seed2['data_select_50'])
print("gradmax            | power avg =", dico_power_avg_seed2['gradmax'], "| energy (j)=", dico_energy_seed2['gradmax'])
# Out:
# ------------------------------------ Exécution seed 0 ------------------------------------
# baseline big       | power avg = 6.976654951690822 | energy (j)= 57766.70300000001
# data selection 50% | power avg = 7.169113288288289 | energy (j)= 31830.863
# gradmax            | power avg = 6.167946677672307 | energy (j)= 74724.674
#
# ------------------------------------ Exécution seed 1 ------------------------------------
# baseline big       | power avg = 6.96576769138035 | energy (j)= 57781.043000000005
# data selection 50% | power avg = 7.120202781516375 | energy (j)= 31741.864
# gradmax            | power avg = 6.170508127031757 | energy (j)= 74027.586
#
# ------------------------------------ Exécution seed 2 ------------------------------------
# baseline big       | power avg = 6.982576683441169 | energy (j)= 58276.585
# data selection 50% | power avg = 7.122304054054054 | energy (j)= 31623.030000000002
# ...

# %%
dico_energy_moy={}
dico_energy_moy['baseline_big']=dico_energy_seed0['baseline_big']+dico_energy_seed1['baseline_big']+dico_energy_seed2['baseline_big']
dico_energy_moy['baseline_big']=dico_energy_moy['baseline_big']/3

dico_energy_moy['data_select_50']=dico_energy_seed0['data_select_50']+dico_energy_seed1['data_select_50']+dico_energy_seed2['data_select_50']
dico_energy_moy['data_select_50']=dico_energy_moy['data_select_50']/3

dico_energy_moy['gradmax']=dico_energy_seed0['gradmax']+dico_energy_seed1['gradmax']+dico_energy_seed2['gradmax']
dico_energy_moy['gradmax']=dico_energy_moy['gradmax']/3

print("------------------------------------ Consommation moyenne énergie ------------------------------------")
print("baseline big       | energy (j)=", dico_energy_moy['baseline_big'])
print("data selection 50% | energy (j)=", dico_energy_moy['data_select_50'])
print("gradmax            | energy (j)=", dico_energy_moy['gradmax'])
# Out:
# ------------------------------------ Consommation moyenne énergie ------------------------------------
# baseline big       | energy (j)= 57941.443666666666
# data selection 50% | energy (j)= 31731.918999999998
# gradmax            | energy (j)= 74446.30200000001

# %%
dico_power_list_moy={}

l=min(len(dico_power_list_seed0['baseline_big']), len(dico_power_list_seed1['baseline_big']), len(dico_power_list_seed2['baseline_big']))

dico_power_list_moy['baseline_big']=np.array(dico_power_list_seed0['baseline_big'][0:l])+np.array(dico_power_list_seed1['baseline_big'][0:l])+np.array(dico_power_list_seed2['baseline_big'][0:l])
dico_power_list_moy['baseline_big']=dico_power_list_moy['baseline_big']/3

l=min(len(dico_power_list_seed0['data_select_50']), len(dico_power_list_seed1['data_select_50']), len(dico_power_list_seed2['data_select_50']))

dico_power_list_moy['data_select_50']=np.array(dico_power_list_seed0['data_select_50'][0:l])+np.array(dico_power_list_seed1['data_select_50'][0:l])+np.array(dico_power_list_seed2['data_select_50'][0:l])
dico_power_list_moy['data_select_50']=dico_power_list_moy['data_select_50']/3

l=min(len(dico_power_list_seed0['gradmax']), len(dico_power_list_seed1['gradmax']), len(dico_power_list_seed2['gradmax']))

dico_power_list_moy['gradmax']=np.array(dico_power_list_seed0['gradmax'][0:l])+np.array(dico_power_list_seed1['gradmax'][0:l])+np.array(dico_power_list_seed2['gradmax'][0:l])
dico_power_list_moy['gradmax']=dico_power_list_moy['gradmax']/3

# %%
def compute_power_cumul(pow_list):
    pow_cumul_list=[]
    pow_cum=0
    for p in pow_list:
        pow_cum+=p
        pow_cumul_list.append(pow_cum)
    return pow_cumul_list

# %%
pow_cumul_baseline_big=compute_power_cumul(dico_power_list_moy['baseline_big'])
pow_cumul_data_select_50=compute_power_cumul(dico_power_list_moy['data_select_50'])
pow_cumul_gradmax=compute_power_cumul(dico_power_list_moy['gradmax'])

# %%
plt.figure(figsize=(10,10))
plt.plot(pow_cumul_baseline_big, label="baseline big")
plt.plot(pow_cumul_data_select_50, label="data selection")
plt.plot(pow_cumul_gradmax, label="gradmax")

plt.legend()
plt.title("évolution puissance cumulée")

plt.show()
